# %% [markdown]
# # Phase 3 Code Challenge Review
#
# Made using resources from the Seattle team - thanks y'all.

# %% [markdown]
# ## Overview
#
# * Gradient Descent
# * Logistic Regression
# * Classification Metrics
# * Decision Trees

# %%
# Imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve, RocCurveDisplay

# %%
# from src.call import call_on_students

# %% [markdown]
# ## Part 1: Gradient Descent

# %% [markdown]
# ### Set Up

# %%
# Grab the data from 'auto-mpg.csv'
mpg_df = pd.read_csv("data/auto-mpg.csv")

# %%
# Explore the data
mpg_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
# Let's plot a simple linear regression line using just the horsepower column
plt.figure(figsize=(8, 6))
sns.regplot(x='horsepower', y='mpg', data=mpg_df, line_kws={"color":"orange"})
plt.title('Relationship Between Horsepower and MPG')
plt.xlim(0, 250)
plt.show()

# %% [markdown]
# The above graph shows an approximate best fit line for the relationship between `horsepower` and `mpg` in our data.

# %% [markdown]
# ### 1) Describe the below chart: What is it showing? What does it tell us?
#
# ![Slope-RSS relationship image](images/slope-rss-relationship.png)

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - The above graph is showing us the relationship between the residual sun of squares and the coefficient on horsepower. RSS is a measure of error, and with gradient descent, we're looking to find the lowest possible error. The purpose of graphing the two is find the coefficient at which RSS is the lowest, aka the bottom of the above curve where slope is about -0.158.

# %% [markdown]
# ### 2) Imagine that you're starting at a slope towards the top upper left corner. Using Zoom's annotate feature, demonstrate how gradient descent would work

# %%
# call_on_students(1)

# %% [markdown]
# ### 3) What is a step size when talking about gradient descent? How does learning rate regulate step size?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - step size is the magnitude of the change in slope that we make each time we calculate a new RSS in searching for the optimal slope to minimize RSS. Learning rate controls how big or small the steps are. A bigger learning rate leads to a larger step.

# %% [markdown]
# ## Part 2: Logistic Regression

# %% [markdown]
# ### 4) Describe a logistic regression model:
#
# - What kind of target is a logistic regression model used for?
# - What are the predictions that a logistic regression model outputs?
# - How is it different from linear regression?
# - Is it a parametric or non-parametric model?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - logistic regression is used for a (binary) discreet target
# - output is always between 0 and 1 and indicates the probability of a certain class
# - linear regression is used for continuous target variables and the resulting coefficients measure the impact of each independent variable on the dependent variable.
# - it is a parametric model

# %% [markdown]
# ### 5) Compare a logistic regression model to any of the other model types we've learned:
#
# - List one benefit of logistic regression when compared to the other model type
# - List one reason the other model type might be more useful

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - logistic regression models are great for predicting outcomes or for classifying records as one of two possiblities given a set of indepedent variables.
# - linear regression might be better when we're trying to do inferential modeling as opposed to predictive modeling. i.e. when we're trying to figure out if and by how much a variable impacts our target variable.

# %% [markdown]
# ## Part 3: Logistic Regression and Classification Metrics with Code
#
# ### Set Up

# %%
# Let's use the same data, but now with a classification target
mpg_class = pd.read_csv('data/auto-mpg-classification.csv')

# %%
# Check this new dataframe out
mpg_class.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0         130    3504          12.0          70
# 1          8         350.0         165    3693          11.5          70
# 2          8         318.0         150    3436          11.0          70
# 3          8         304.0         150    3433          12.0          70
# 4          8         302.0         140    3449          10.5          70
#
#    origin  target
# 0       1       0
# 1       1       1
# 2       1       0
# 3       1       1
# 4       1       1

# %% [markdown]
# ### 6) Prepare our data for modeling:
#
# 1. Perform a train/test split
# 2. Scale the inputs

# %%
# call_on_students(1)

# %%
# Train-test split
# Set test_size=0.33 and random_state=42
X = mpg_class.drop('target', axis=1)
y = mpg_class['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.33)

# %%
# Scale the data
scaler = StandardScaler()


X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_train_scaled

X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns=X_test.columns, index=X_test.index)
X_test_scaled
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 78   -0.821090     -0.864212   -0.849619 -0.859545      0.915849   -0.956721
# 274  -0.821090     -0.621906    0.354058 -0.146801      0.004875    0.624301
# 246  -0.821090     -0.912673   -1.085121 -1.317065      0.282128    0.624301
# 55   -0.821090     -0.912673   -0.823452 -1.134763      1.906038   -1.220225
# 387  -0.821090     -0.437753   -0.404782 -0.152682     -0.034733    1.678316
# ..         ...           ...         ...       ...           ...         ...
# 232  -0.821090     -0.331139   -0.352448 -0.211489      0.123697    0.360797
# 193  -0.821090     -0.970826   -1.294456 -1.040671      2.579367    0.097294
# 238  -0.821090     -0.854519   -0.614117 -0.858369     -0.628846    0.360797
# 152   0.398815      0.628392   -0.771118  0.602403      2.104076   -0.166210
# 346  -0.821090     -0.776981   -1.006620 -0.828965     -0.311986    1.414812
#
#       origin
# 78   0.48795
# 274  0.48795
# 246  1.75662
# 55  -0.78072
# 387 -0.78072
# ..       ...
# 232 -0.78072
# 193 -0.78072
# 238  0.48795
# 152 -0.78072
# 346 -0.78072
#
# [130 rows x 7 columns]

# %% [markdown]
# ### 7) Explore the `target` column and our model-less baseline
#
# 1. What is the breakdown of the `target` column in our training data?
# 2. What would a model-less baseline look like in this context?
# 3. How accurate would that model-less understanding be on our test data?

# %%
# call_on_students(1)

# %% [markdown]
# #### Part 1: explore the target column breakdown in train data

# %%
# Code to explore
y_train.describe()
# Out:
# count    262.000000
# mean       0.255725
# std        0.437103
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %% [markdown]
# #### Answer:
#
# - target train data implies that 26% of time target variable is 1, given target is either 0 or 1 and mean of target column is 0.256

# %% [markdown]
# #### Part 2: What would a model-less baseline look like in this context?
#
# #### Answer:
#
# - baseline is 26% (datset is unbalance)

# %% [markdown]
# #### Part 3: How accurate would that baseline be on test data?

# %%
# Code to find the answer
y_test.describe()
# Out:
# count    130.000000
# mean       0.246154
# std        0.432436
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: target, dtype: float64

# %% [markdown]
# #### Answer:
#
# - mean of test dataset is 0.246, so baseline would be off by about 1 percentage point on test data.

# %% [markdown]
# ### 8) What is one problem you could foresee based on this breakdown, and what is one strategy you could employ to address that problem?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - based on this breakdown the dataset is very unbalance with there being far more rows where target equals 0 than there are rows where target equals 1. One thing you could do to fix this is upsampling the minority class. You could do this using SMOTE from sklearn.

# %% [markdown]
# ### 9) Fit a logistic regression model, and plot a confusion matrix of the results on our test set

# %%
# call_on_students(1)

# %%
# Fit a logistic regression model
# Name the model `logreg` and set random_state = 42
logreg = LogisticRegression()
logreg_model = logreg.fit(X_train_scaled, y_train)

# %%
# Plot a confusion matrix on the test data

ConfusionMatrixDisplay.from_estimator(logreg_model, X_test_scaled, y_test, cmap="plasma")

# %% [markdown]
# ### 10) Calculate the accuracy, precision, recall and f1-score for the test set
#
# You can use the confusion matrix above, or sklearn functions

# %%
# call_on_students(1)

# %%
# Accuracy
y_hat_test = logreg_model.predict(X_test_scaled)

accuracy_score(y_test, y_hat_test)
# Out:
# 0.9076923076923077

# %%
# Precision
precision_score(y_test, y_hat_test)
# Out:
# 0.8846153846153846

# %%
# Recall
recall_score(y_test, y_hat_test)
# Out:
# 0.71875

# %%
# F1-Score
f1_score(y_test, y_hat_test)
# Out:
# 0.7931034482758621

# %% [markdown]
# ### 11) Calculate the ROC-AUC on the test set, and plot the ROC curve
#
# For this you'll definitely want to use the sklearn functions!

# %%
# call_on_students(1)

# %%
# Calculate roc-auc
#roc_auc_score, roc_curve
roc_auc_score(y_test, logreg_model.predict_proba(X_test_scaled)[:, 1])
# Out:
# 0.9815051020408163

# %%
# Plot the ROC curve
RocCurveDisplay.from_estimator(logreg_model, X_test_scaled, y_test)

# %% [markdown]
# ### 12) Evaluate! Based on the metrics of our test data, how is our model doing?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - model has 90% accuracy meaning model predicts correctly 90% of the time.
# - model has 88% precission meaning that 88% of the model's predicted 1's were true 1's.
# - model has 72% recall aka true positive rate. the model correctly identifed 72% of the true 1's.
# - model has 80% f1 score. this is a combination of recall and precision.
# - An AUC of 0.98 indicates that the model predicts correctly 98% of the time.

# %% [markdown]
# ## Part 4: Decision Trees
#
# ### Set Up - Generating 1-split trees to compare

# %%
# Creating two different decision trees with a single split
dt_maxdepth1_v1 = DecisionTreeClassifier(max_depth=1, random_state = 42)
dt_maxdepth1_v2 = DecisionTreeClassifier(max_depth=1, random_state = 42)

# Training the two trees on different columns
dt_maxdepth1_v1.fit(X_train[['weight']], y_train)
dt_maxdepth1_v2.fit(X_train[['origin']], y_train)
# Out:
# DecisionTreeClassifier(max_depth=1, random_state=42)

# %%
# Tree based on 1st column
plot_tree(dt_maxdepth1_v1, feature_names=['weight'], filled=True);

# %%
# Tree based on 2nd column
plot_tree(dt_maxdepth1_v2, feature_names=['origin'], filled=True);

# %% [markdown]
# #### Result:
#
# (showing the image output incase there is a problem with the above code to generate and visualize these trees)
#
# | Version 1: Weight | Version 2: Origin |
# | ----------------- | ----------------- |
# | ![max depth 1 - version 1](images/dt-maxdepth1-v1.png) | ![max depth 1 - version 2](images/dt-maxdepth1-v2.png) |

# %% [markdown]
# ### 13) Which of these trees does a better job splitting the data? How can you tell?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - the weight tree does a better job. You can see far fewer of the minority class in the final nodes than you do in the final nodes of the origin tree. also the two gini scores on the bottom nodes of the weight tree are closer to zero than the two for the origin tree.

# %% [markdown]
# ### 14) Fit a decision tree model, and plot a confusion matrix of the results on our test set

# %%
# call_on_students(1)

# %%
# Fit a decision tree model
# Name the model `dt` and set random_state = 42
dt = DecisionTreeClassifier(criterion = 'gini', random_state=42)
dt.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Plot a confusion matrix on the test data
ConfusionMatrixDisplay.from_estimator(dt, X_test_scaled, y_test)

# %%
# Code to visualize the ROC curves for the models we've done
#fig, ax = plt.subplots()
RocCurveDisplay.from_estimator(dt, X_test_scaled, y_test)
RocCurveDisplay.from_estimator(logreg, X_test_scaled, y_test)


plt.title("Receiver Operating Characteristic Curves\n(Evaluated on Test Set)")
plt.show()

# %% [markdown]
# ### 15) Which is the better model according to ROC-AUC score? How can you tell?

# %%
# call_on_students(1)

# %% [markdown]
# #### Answer:
#
# - The logistic regression model has a higher AUC at 0.98 vs. 0.90 for the decision tree. with that said, the log reg model is better as it predicts the correct result more often than the decision tree model.
